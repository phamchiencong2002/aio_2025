# %%
# %pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    -- ------------------------------------- 7.9/113.8 MB 48.7 MB/s eta 0:00:03
#    --- ------------------------------------ 10.5/113.8 MB 29.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 14.9/113.8 MB 26.1 MB/s eta 0:00:04
#    ------- -------------------------------- 21.5/113.8 MB 27.2 MB/s eta 0:00:04
#    -------- ------------------------------- 24.4/113.8 MB 24.1 MB/s eta 0:00:04
#    --------- ------------------------------ 27.5/113.8 MB 22.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 31.5/113.8 MB 21.7 MB/s eta 0:00:04
#    ------------ --------------------------- 36.4/113.8 MB 22.0 MB/s eta 0:00:04
#    -------------- ------------------------- 42.2/113.8 MB 22.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 49.0/113.8 MB 23.6 MB/s eta 0:00:03
#    -------------------- ------------------- 56.9/113.8 MB 24.8 MB/s eta 0:00:03
# ...

# %%
import torch

# %%
x = torch.tensor([1.0, 5.0, -4.0])

output = torch.sigmoid(x)
print(output)
# Out:
# tensor([0.7311, 0.9933, 0.0180])

# %%
import torch.nn as nn

class MySigmoid(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, x):
        return 1 / (1 + torch.exp(-x))
    
my_sigmoid = MySigmoid()
x = torch.tensor([1, 5, -4, 3, -2])
output = my_sigmoid(x)
print(output)
# Out:
# tensor([0.7311, 0.9933, 0.0180, 0.9526, 0.1192])

# %%
from abc import ABC, abstractmethod

class Person(ABC):
    def __init__(self, name: str, yob: int):
        self._name = name
        self._yob = yob
    
    def get_yob(self):
        return self._yob
    
    @abstractmethod
    def describe(self):
        pass

class Student(Person):
    def __init__(self, name: str, yob: int, grade: str):
        super().__init__(name=name, yob=yob)
        self.__grade = grade
    
    def describe(self):
        return f"Student - Name: {self._name}, YOB: {self._yob}, Grade: {self.__grade}"

class Teacher(Person):
    def __init__(self, name: str, yob: int, subject: str):
        super().__init__(name=name, yob=yob)
        self.__subject = subject
    
    def describe(self):
        return f"Teacher - Name: {self._name}, YOB: {self._yob}, Subject: {self.__subject}"
    
class Doctor(Person):
    def __init__(self, name: str, yob: int, specialization: str):
        super().__init__(name=name, yob=yob)
        self.__specialization = specialization
    
    def describe(self):
        return f"Doctor - Name: {self._name}, YOB: {self._yob}, Specialization: {self.__specialization}"

# %%
student1 = Student(name="Alice", yob=2000, grade="A")
student1.describe()

teacher1 = Teacher(name="Mr. Smith", yob=1980, subject="Mathematics")
teacher1.describe()

doctor1 = Doctor(name="Dr. Brown", yob=1975, specialization="Cardiology")
doctor1.describe()
# Out:
# 'Doctor - Name: Dr. Brown, YOB: 1975, Specialization: Cardiology'

# %%
class Ward:
    def __init__(self, name: str):
        self.__name = name
        self.__list_people = []
    
    def add_person(self, person: Person):
        self.__list_people.append(person)
    
    def describe(self):
        print(f"Ward Name: {self.__name}")
        for person in self.__list_people:
            person.describe()
